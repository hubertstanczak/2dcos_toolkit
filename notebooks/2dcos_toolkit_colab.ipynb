# %% [markdown]
# <a href="https://colab.research.google.com/github/hubertstanczak/2dcos_toolkit/blob/main/notebooks/2dcos_toolkit_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 2DCOS Analysis Toolkit for CD
# Perform complete Two-Dimensional Correlation Spectroscopy (2DCOS) analysis
# on Circular Dichroism (CD) data, including MRE conversion, preprocessing,
# correlation map computation, peak detection, and result export.

# %%
#@title **Setup**
#@markdown Prepare the environment for analysis in Google Colab. Run this cell once before starting the analysis.

import os
import sys
import shutil
import subprocess
from pathlib import Path

repo_url = "https://github.com/hubertstanczak/2dcos_toolkit.git"
repo_name = "2dcos_toolkit"

os.chdir("/content")

if Path(repo_name).exists():
    shutil.rmtree(repo_name)

print("Installing dependencies...")

subprocess.check_call(["git", "clone", "--depth", "1", repo_url, repo_name],
                      stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

subprocess.check_call([sys.executable, "-m", "pip", "install", "-e", repo_name],
                      stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)


for key in list(sys.modules):
    if key.startswith("dcos_toolkit"):
        del sys.modules[key]

try:
    from dcos_toolkit.api import (
        setup_logging,
        init_session,
        load_input_data_and_parse,
        compute_mre,
        generate_mre_plots,
        compute_2dcos,
        visualize_session,
        package_results,
    )

    setup_logging(level="INFO", style="colab")
    print("Setup complete.")

except Exception as e:
    print(f"Setup failed. Error: {e}")
    print("Try: Runtime -> Restart session")

# %%
#@title **Data Upload**
#@markdown Upload one or more files containing CD spectra in **.csv** format or a **.zip** archive containing such files.
#@markdown
#@markdown ___
#@markdown ### Expected file structure:
#@markdown
#@markdown **2D Table:**
#@markdown - **Row 1:** measured temperature (°C) for consecutive spectra
#@markdown - **Column 1:** wavelength λ (nm)
#@markdown - **Table body:** CD values (mdeg)
#@markdown
#@markdown **JASCO instrument data:** CD signal is read from Channel 1.
#@markdown ___
#@markdown Set a job name (used as the prefix for the output folder: `<job_name>'_2DCOS_results.zip`.
job_name = "my_analysis"  #@param {type:"string"}

from pathlib import Path
import shutil
import re
from google.colab import files
from IPython.display import clear_output

input_dir  = Path("data/input_cd")
base_output_dir = Path("data/results")

final_output_dir = base_output_dir / job_name

SESSION = init_session(job_name=job_name, output_dir=str(final_output_dir))
SESSION.input_dir = input_dir

SESSION.input_dir.mkdir(parents=True, exist_ok=True)
SESSION.output_dir.mkdir(parents=True, exist_ok=True)

print("Upload one or more CD data files in .csv format or .zip archive containing such files." )

for directory in [SESSION.input_dir, SESSION.output_dir]:
    if directory.exists():
        for item in directory.iterdir():
            try:
                if item.is_dir():
                    shutil.rmtree(item)
                else:
                    item.unlink()
            except Exception:
                pass

uploaded = files.upload()

if uploaded:
    for name, data in uploaded.items():
        clean_name = re.sub(r' \(\d+\)', '', name)

        (SESSION.input_dir / clean_name).write_bytes(data)

    clear_output(wait=True)


    try:
        load_input_data_and_parse(SESSION, paths=[SESSION.input_dir])
    except (FileNotFoundError, RuntimeError, ValueError) as e:
        print(str(e))
else:
    print("Upload cancelled.")

# %%
#@title **MRE Calculation (CD → MRE)**
#@markdown Enter the sample parameters to convert the **CD** signal to **MRE** (mean residue ellipticity).
#@markdown ___
#@markdown ### MRE is calculated using the formula:
#@markdown $$[\theta] = \frac{M \cdot \theta_{\text{obs}}}{10 \cdot c \cdot l \cdot n}$$
#@markdown **Where:**
#@markdown - **M (molar_mass)** – peptide molar mass *(g/mol)*
#@markdown - **$\theta_{\text{obs}}$** – measured ellipticity *(mdeg)*
#@markdown - **c (concentration)** – sample concentration *(mg/ml)*
#@markdown - **l (path_length)** – optical path length *(cm)*
#@markdown - **n (residues_number)** – number of peptide bonds *(≈ number of residues)*
#@markdown ---
#@markdown Entered parameters are applied to **all** datasets.
#@markdown
#@markdown For samples with different physical parameters, run the notebook **separately** for each one.

molar_mass     = 1.0   #@param {type:"number"}
concentration  = 1.0   #@param {type:"number"}
path_length    = 1.0   #@param {type:"number"}
residues_number = 1.0  #@param {type:"number"}



try:
    compute_mre(
        SESSION,
        molar_mass=molar_mass,
        residues_number=residues_number,
        concentration=concentration,
        path_length=path_length,
    )
except (RuntimeError, ValueError, TypeError, NameError) as e:
    print(str(e))

# %%
#@title **1D Spectra visualization**
#@markdown Generate **1D plots** for the loaded spectra datasets.
#@markdown ___
#@markdown  Choose whether the plots should display raw CD signal (mdeg) or calculated MRE [θ].
#@markdown
#@markdown **Note:** The **MRE** mode requires prior execution of the **MRE Calculation** step.


try:
    plot_mode = "MRE [θ]"  #@param ["MRE [θ]", "CD [mdeg]"]

    use_mre = (plot_mode == "MRE [θ]")

    generate_mre_plots(
        SESSION,
        use_mre_for_plot=use_mre,
    )

except KeyboardInterrupt:
    print("1D Spectra visualization cancelled.")

except RuntimeError as e:
    print(str(e))

# %%
#@title **2DCOS calculation**
#@markdown Compute 2D correlation maps for **synchronous (Φ)** and **asynchronous (Ψ)** for all processed datasets.
#@markdown ___
#@markdown Choose whether to use the raw CD signal (mdeg) or the calculated MRE [θ]:
#@markdown
#@markdown **Note:** The **MRE** mode requires prior execution of the **MRE Calculation** step.
dcos_mode =  "MRE [θ]"  #@param ["MRE [θ]", "CD [mdeg]"]
#@markdown Choose **reference spectrum**, which will be used in the calculations:
reference_type = "mean"  #@param ["mean", "first", "last", "none"]
#@markdown - **mean**: subtract the mean spectrum
#@markdown - **first**: subtract the first spectrum
#@markdown - **last**: subtract the last spectrum
#@markdown - **none**: no subtraction (uses the original spectra)

use_mre_bool = (dcos_mode == "MRE [θ]")

try:
    compute_2dcos(
        SESSION,
        use_mre_for_2dcos=use_mre_bool,
        reference_type=reference_type,
    )

except KeyboardInterrupt:
    print("2DCOS calculations cancelled.")

except (RuntimeError, ValueError) as e:
    print(str(e))

# %%
#@title **2DCOS maps visualization**
#@markdown  Generate **2DCOS maps** (Φ + Ψ) in high resolution with optional peak labeling.
#@markdown ___
#@markdown Select the colormap:
colormap = "jet" #@param ["jet", "coolwarm", "seismic", "bwr", "RdBu_r"]
#@markdown ___
#@markdown ### Peak annotation
#@markdown Select whether to mark peaks on the mirrored halves of the map:
mark_mirror_peaks = True  #@param {type:"boolean"}
#@markdown - If `Checked`, peaks are marked on both symmetric halves of the map (mirrored across the diagonal).
#@markdown - If `Unchecked`, peaks are marked only on one half (above the diagonal).

#@markdown Select the number of peaks to label in each category (0–5).
#@markdown
#@markdown Peaks are detected on the half of the map above the diagonal.
#@markdown
#@markdown **Synchronous map Φ** (diagonal / positive cross-peaks / negative cross-peaks):
n_sync_diag_peaks = "0"          #@param ["0","1","2","3","4","5"]
n_sync_cross_max_peaks = "0"     #@param ["0","1","2","3","4","5"]
n_sync_cross_min_peaks = "0"     #@param ["0","1","2","3","4","5"]

#@markdown **Asynchronous map Ψ** (positive cross-peaks / negative cross-peaks):
n_async_cross_max_peaks = "0"    #@param ["0","1","2","3","4","5"]
n_async_cross_min_peaks = "0"    #@param ["0","1","2","3","4","5"]





try:
    visualize_session(
        SESSION,
        colormap=colormap,
        mark_mirror_peaks=mark_mirror_peaks,
        n_sync_diag_peaks=int(n_sync_diag_peaks),
        n_sync_cross_max_peaks=int(n_sync_cross_max_peaks),
        n_sync_cross_min_peaks=int(n_sync_cross_min_peaks),
        n_async_cross_max_peaks=int(n_async_cross_max_peaks),
        n_async_cross_min_peaks=int(n_async_cross_min_peaks),
    )

except KeyboardInterrupt:
    print("2DCOS maps visualization cancelled.")

except (RuntimeError, ValueError) as e:
    print(str(e))

# %%
#@title **Export results**
#@markdown Select which items to include in the **.zip archive** (for download in Colab).
#@markdown ___
#@markdown ### Archive contents

export_input_files =    True #@param {type:"boolean"}
#@markdown Original input files (.csv)

export_mre_tables =     True #@param {type:"boolean"}
#@markdown MRE tables (.csv)

export_1d_plots =       True #@param {type:"boolean"}
#@markdown 1D plots (CD/MRE) (.png)

export_2dcos_matrices = True #@param {type:"boolean"}
#@markdown 2DCOS matrices (.csv)

export_2dcos_maps =     True #@param {type:"boolean"}
#@markdown 2DCOS maps (.png)

from google.colab import files

try:
    zip_path = package_results(
        SESSION,
        include_input_file=export_input_files,
        include_mre=export_mre_tables,
        include_mre_plot=export_1d_plots,
        include_2dcos=export_2dcos_matrices,
        include_2dcos_plot=export_2dcos_maps,
    )
    files.download(str(zip_path))
except (RuntimeError, ValueError) as e:
    print(str(e))

# %% [markdown]
# # How to use this notebook
# ---
#
# ### Data requirements
# **Supported formats** - `.csv` or `.zip` containing `.csv` files.
#
# 1. **JASCO Exports** - Native ASCII exports are supported (Channel 1 data is extracted automatically).
#
# 2. **Spreadsheets** - Requies a specific table latout:
# - Row 1 (header): temperature values,
# - Column 1: wavelength (nm),
# - Table body: CD values (mdeg).
#
# ---
#
# ### Analysis workflow
# 1. **Setup** - Initialize the environment, clone the repository, and load backend functions.
#
# 2. **Input data** - Upload raw data file(s) via the Colab file picker. Unsupported file formats are automatically skipped.
#
# 3. **CD parameters for MRE calculation** - Convert raw CD signal to MRE.
# - Required sample parameters: molar mass, concentration, path length, number of residues.
# - Parameters are applied to all datasets in the notebook. For samples with different physical parameters, run the notebook separately.
#
# 4. **1D spectra visualization** - Generate 1D plots of either raw CD (mdeg) or calculated MRE [θ].
# - Note: MRE mode requires the previous step (MRE Calculation).
#
# 5. **2DCOS Calculation** - Compute Synchronous ($\Phi$) and Asynchronous ($\Psi$) correlation maps using a selected reference spectrum.
#
# 6. **2DCOS Visualization** - Generate high-resolution combined contour plots with customizable colormaps and optional automatic peak annotation.
# - Peaks are detected only on the upper triangle of the map (above the diagonal).
# - Optionally, mirror peaks can be marked symmetrically.
# - Specify the maximum number of peaks to mark for each category (0–5) for both synchronous and asynchronous maps.
#
# 7. **Export Results** - Select desired output artifacts and download a ZIP archive. Results for each sample are organized into dedicated subfolders.
#
# ---
#
# ### Interpretation Guide
#
# Correlation maps are interpreted as follows:
#
# **Synchronous map (Φ):**
# - Diagonal peaks indicate the magnitude of change at a given wavelength under temperature variation.
# - Cross-peaks determine the direction of changes for a pair of wavelengths: if positive, both signals change in the same direction (both increase or decrease); if negative, they change in opposite directions (one increases, the other decreases).
#
# **Asynchronous map (Ψ):**
# - Analysis of cross-peaks allows determination of the sequence of events. The same wavelength pair is analyzed on both the synchronous and asynchronous maps. The order of changes is interpreted by comparing the signs on both maps according to Noda's rules:
#
# $
# \begin{array}{|c|c|l|}
# \hline
# \text{Φ Sign} & \text{Ψ Sign} & \text{Interpretation} \\
# \hline
# + & + & \text{Change at } \lambda_1 \text{ occurs before } \lambda_2 \\
# \hline
# - & - & \text{Change at } \lambda_1 \text{ occurs before } \lambda_2 \\
# \hline
# + & - & \text{Change at } \lambda_2 \text{ occurs before } \lambda_1 \\
# \hline
# - & + & \text{Change at } \lambda_2 \text{ occurs before } \lambda_1 \\
# \hline
# \end{array}
# $
